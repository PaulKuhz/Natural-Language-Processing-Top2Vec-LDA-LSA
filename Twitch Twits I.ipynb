# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import emoji
#from emoji import UNICODE_EMOJI
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### 1. EDA for Alien

# %% [markdown]
# ![61nUUqTlgIL._CR0,130,640,640_UX256.jpg](attachment:61nUUqTlgIL._CR0,130,640,640_UX256.jpg)

# %%
alien = pd.read_csv("alien_dataset.csv")
alien
# Out:
#      Unnamed: 0  rank           id    user_id           user_login  \
# 0             1     1  46162267500   10774989         glowpinkstah
# 1             2     2  46161477548  279986684           dkittycone
# 2             3     3  39931426872  751779249            fatalfayt
# 3             4     4  40329419529   62996835            eurosdown
# 4             5     5  47282402509  748943826          lilmelibebe
# ..          ...   ...          ...        ...                  ...
# 872         873    54  40325445705  439299183  the_tired_streamer6
# 873         874    55  47278757885  826769032           p1geonlord
# 874         875    56  41371225147  561500955          billytheg24
# 875         876    57  47278766797  150495616      thestorycluster
# 876         877    58  46160541036  188083820        aspargussalad
#
#                user_name  game_id         game_name  type  \
# 0           glowpinkstah   458443  Alien: Isolation  live
# ...

# %%
len(alien.index)
# Out:
# 877

# %%
alien.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
alien.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            6
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %%
alien.dropna(inplace = True)

# %% [markdown]
# Let's drop these 6 rows since the streaming titles are complete independet from each other.

# %%
alien.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 2. EDA for Chess

# %% [markdown]
# ![communityIcon_k55yb9gfm6v81.png](attachment:communityIcon_k55yb9gfm6v81.png)

# %%
chess = pd.read_csv("chess_dataset.csv")
chess.head()
# Out:
#    Unnamed: 0  rank           id    user_id          user_login  \
# 0           1     1  39933271352  478353255          alexbanzea
# 1           2     2  41374573499  477672373       chessdojolive
# 2           3     3  39753739911  180854563       tcec_chess_tv
# 3           4     4  39931921288  262970665          froyachess
# 4           5     5  46163588428  662279717  grandmistresseyrun
#
#             user_name  game_id game_name  type  \
# 0          alexbanzea      743     Chess  live
# 1       ChessDojoLive      743     Chess  live
# 2       TCEC_Chess_TV      743     Chess  live
# 3          froyachess      743     Chess  live
# 4  GrandMistressEyrun      743     Chess  live
#
#                                                title  viewer_count  \
# 0              I AM ALIVE (unlike my rating) !london           654
# 1  Puzzle Survival Slowrun (goal: 67) | !training...           628
# 2                       Season 23 - Premier Division           185
# ...

# %%
len(chess.index)
# Out:
# 589

# %%
chess.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
 chess.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            1
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %%
chess.dropna(inplace = True)

# %% [markdown]
# ### 3. EDA for Cyberpunk

# %% [markdown]
# ![cyberpunk_2077_neon_square_icon_by_ylfaer_dekr8fg-fullview.png](attachment:cyberpunk_2077_neon_square_icon_by_ylfaer_dekr8fg-fullview.png)

# %%
cyberpunk = pd.read_csv("cyberpunk_dataset.csv")
cyberpunk.head()
# Out:
#    Unnamed: 0  rank           id    user_id    user_login     user_name  \
# 0           1     1  39754640695  582765062    premiertwo    PremierTwo
# 1           2     2  39931414552  585904842    usagikira_    usagikira_
# 2           3     3  46162165388   76457776  alexjordanvo  AlexJordanVO
# 3           4     4  41373870539   72011080        tyriss        Tyriss
# 4           5     5  47282538685  198400251    kdotdagawd    KDotDaGawd
#
#    game_id       game_name  type  \
# 0    65876  Cyberpunk 2077  live
# 1    65876  Cyberpunk 2077  live
# 2    65876  Cyberpunk 2077  live
# 3    65876  Cyberpunk 2077  live
# 4    65876  Cyberpunk 2077  live
#
#                                                title  viewer_count  \
# 0  **STORY NIGHT** The 🤜 🤛continues until morale ...           788
# 1   just a cyberbun playing game with much knowledge           107
# 2                    CyberPumped for Corpo Netrunner            93
# ...

# %%
len(cyberpunk.index)
# Out:
# 1400

# %%
cyberpunk.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
cyberpunk.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            6
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %%
cyberpunk.dropna(inplace = True)

# %% [markdown]
# ### 4. EDA for Genshin

# %% [markdown]
# ![genshinimpactrevenue-r225x.jpeg](attachment:genshinimpactrevenue-r225x.jpeg)

# %%
genshin = pd.read_csv("genshin_dataset.csv")
genshin.head()
# Out:
#    Unnamed: 0  rank           id    user_id     user_login      user_name  \
# 0           1     1  47282469309   44390855      enviosity      Enviosity
# 1           2     2  46161660268   26973975        wardiii        Wardiii
# 2           3     3  40329377529   47081094  murderofbirds  MurderofBirds
# 3           4     4  46161631804  446510977      jasperine      jasperine
# 4           5     5  41373950827   45223790        cherimu        Cherimu
#
#    game_id       game_name  type  \
# 0   513181  Genshin Impact  live
# 1   513181  Genshin Impact  live
# 2   513181  Genshin Impact  live
# 3   513181  Genshin Impact  live
# 4   513181  Genshin Impact  live
#
#                                                title  viewer_count  \
# 0        !DROPS | NEW EVENT + MONDAY RESET | Day 743          5000
# 1  #sponsored Genshin Impact Bounty! | !HeroWars ...          2377
# 2                          SUMERU ARCHON QUEST ACT 3           684
# ...

# %%
len(genshin.index)
# Out:
# 1299

# %%
genshin.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
genshin.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 5. EDA for GTA

# %% [markdown]
# ![d8ubq4a-5db8eaf9-e314-4f75-a7f1-4dda9ce1a6f3.png](attachment:d8ubq4a-5db8eaf9-e314-4f75-a7f1-4dda9ce1a6f3.png)

# %%
gta = pd.read_csv("gta_dataset.csv")
gta.head()
# Out:
#    Unnamed: 0  rank           id    user_id  user_login   user_name  game_id  \
# 0           1     1  46164008444   13884994      zerkaa      Zerkaa    32982
# 1           2     2  47284119117   84316241       penta       PENTA    32982
# 2           3     3  46161950700  484563826   sparkykne   SparkyKNE    32982
# 3           4     4  47282857597   89486159  bananabrea  bananabrea    32982
# 4           5     5  41374427563  214560121    brookeab    BrookeAB    32982
#
#             game_name  type  \
# 0  Grand Theft Auto V  live
# 1  Grand Theft Auto V  live
# 2  Grand Theft Auto V  live
# 3  Grand Theft Auto V  live
# 4  Grand Theft Auto V  live
#
#                                                title  viewer_count  \
# 0                🟩 TOMMY T 🟩 | NoPixel WL | !nprules         10053
# 1  NoPixel | Cadet Audit | MIke Later | Variety a...          5994
# 2          Sparky Kane | MDM | Nopixel WL | !nordvpn          3014
# ...

# %%
len(gta.index)
# Out:
# 1594

# %%
gta.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
gta.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 6. EDA for JC

# %% [markdown]
# ![aHR0cHM6Ly93d3cucG9kY2hhc2VyLmNvbS9pbWFnZXMvbWlzc2luZy1pbWFnZS5wbmc=.jpeg](attachment:aHR0cHM6Ly93d3cucG9kY2hhc2VyLmNvbS9pbWFnZXMvbWlzc2luZy1pbWFnZS5wbmc=.jpeg)

# %%
jc = pd.read_csv("jc_dataset.csv")
jc.head()
# Out:
#    Unnamed: 0  rank           id    user_id  user_login   user_name  game_id  \
# 0           1     1  41374043483  119128245  jaystreazy  jaystreazy   509658
# 1           2     2  47282550125   78219897   akademiks   Akademiks   509658
# 2           3     3  47282504557   22562338     buffpup     BuffPup   509658
# 3           4     4  41374004843  192188954       milky       Milky   509658
# 4           5     5  41369916747  590035829  otknetwork  OTKnetwork   509658
#
#        game_name  type                                              title  \
# 0  Just Chatting  live  TWITCHCON AFTERMATH - san diego, california, u...
# 1  Just Chatting  live  KANYE JUST DROPPED THE BEST DOCUMENTARY OF 202...
# 2  Just Chatting  live                 barkborkwoofawoo ||  !socials !ADV
# 3  Just Chatting  live  🎃🦇 ⋆ Hanging out & Chatting with your favorite...
# 4  Just Chatting  live            LOFI 24/7 | !website !song !art !emotes
#
#    viewer_count            started_at language  \
# ...

# %%
len(jc.index)
# Out:
# 1397

# %%
jc.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
jc.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          1
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 7. EDA for League of Legends

# %% [markdown]
# ![league_of_legends_honeycomb_icon_by_razzgraves_d97rqpj-fullview.png](attachment:league_of_legends_honeycomb_icon_by_razzgraves_d97rqpj-fullview.png)

# %%
league = pd.read_csv("league_dataset.csv")
league.head()
# Out:
#    Unnamed: 0  rank           id    user_id    user_login     user_name  \
# 0           1     1  40329280265  127661213     callmetog     CallMeTOG
# 1           2     2  46161875660  782168204       ktee140       KTee140
# 2           3     3  46161870140   85699403      hatakewr      HatakeWR
# 3           4     4  39931486216   80976150      fasusasu      Fasusasu
# 4           5     5  47282679309  152586770  jeremiahhhh_  jeremiahhhh_
#
#    game_id                     game_name  type  \
# 0   514858  League of Legends: Wild Rift  live
# 1   514858  League of Legends: Wild Rift  live
# 2   514858  League of Legends: Wild Rift  live
# 3   514858  League of Legends: Wild Rift  live
# 4   514858  League of Legends: Wild Rift  live
#
#                                                title  viewer_count  \
# 0                           im stressed out !silence           133
# 1                         Losing Brain Cells Enjoyer            19
# ...

# %%
len(genshin.index)
# Out:
# 1299

# %%
genshin.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
genshin.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 8. EDA for Valo

# %% [markdown]
# ![2944201.webp](attachment:2944201.webp)

# %%
valo = pd.read_csv("valo_dataset.csv")
valo.head()
# Out:
#    Unnamed: 0  ...1           id    user_id     user_login      user_name  \
# 0           1     1  46163375196   39393054         scream         ScreaM
# 1           2     2  47283329149  420488297  frtingglitter  FrtingGlitter
# 2           3     3  41374651483   26202775       steel_tv       steel_tv
# 3           4     4  47283658909  119015407          dashy          Dashy
# 4           5     5  41374703083   29039515           brax           brax
#
#    game_id game_name  type                                              title  \
# 0   516575  VALORANT  live      helllo some duo w/beasty -  Follow my !social
# 1   516575  VALORANT  live  ANXIOUS LADY | !expressvpn !valoranttracker !b...
# 2   516575  VALORANT  live                              so much fun! | !razer
# 3   516575  VALORANT  live                        cmon now @dashyszn !socials
# 4   516575  VALORANT  live                 RANK 1 PLAYING ON ALT |  @brax1wnl
#
#    viewer_count            started_at language  \
# ...

# %%
len(valo.index)
# Out:
# 1598

# %%
valo.dtypes
# Out:
# Unnamed: 0        int64
# ...1              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
valo.isnull().sum()
# Out:
# Unnamed: 0       0
# ...1             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          1
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 9. EDA for Virtual Casino

# %% [markdown]
# ![256x256bb.jpeg](attachment:256x256bb.jpeg)

# %%
virtualcasino = pd.read_csv("virtualcasino_dataset.csv")
virtualcasino.head()
# Out:
#    Unnamed: 0  rank           id    user_id      user_login       user_name  \
# 0           1     1  39930252200  798306633  jet_officially  jet_officially
# 1           2     2  39930855288  798304395   sol_offiziell   sol_offiziell
# 2           3     3  39931528792  434079644        ewfw5kkm        ewfw5kkm
# 3           4     4  39931771928  825933040     roiboydelhi     roiboydelhi
# 4           5     1  39933518616  798304395   sol_offiziell   sol_offiziell
#
#    game_id       game_name  type                               title  \
# 0    29452  Virtual Casino  live     GORDÃ0 DA BLAZE    ESCORREGA O!
# 1    29452  Virtual Casino  live  CASINOOOOO GOD - 1000$ and a dream
# 2    29452  Virtual Casino  live                BIG Bonus every day🎁
# 3    29452  Virtual Casino  live                roiboy mega stream !
# 4    29452  Virtual Casino  live  CASINOOOOO GOD - 1000$ and a dream
#
#    viewer_count            started_at language  \
# ...

# %%
len(virtualcasino.index)
# Out:
# 54

# %%
virtualcasino.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
virtualcasino.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %% [markdown]
# ### 10. EDA for WoW

# %%
wow = pd.read_csv("wow_dataset.csv")
wow.head()
# Out:
#    Unnamed: 0  rank           id   user_id  user_login   user_name  game_id  \
# 0           1     1  40329525913  59624901        payo        Payo    18122
# 1           2     2  46162298284  23179441    strippin    Strippin    18122
# 2           3     3  39931813160  53649632       naowh       Naowh    18122
# 3           4     4  41374821931  27992608  pikabooirl  Pikabooirl    18122
# 4           5     5  47283360461  17206877      yumytv      yumytv    18122
#
#            game_name  type                                              title  \
# 0  World of Warcraft  live  NAXX 25 GDKP EU MAGE TOMORROW!! || WORLD OF TH...
# 1  World of Warcraft  live                    Games - Naxxflix N Chill @ 1pst
# 2  World of Warcraft  live  Dragonflight prep <ECHO> Beta UI up! | WORLD F...
# 3  World of Warcraft  live         GG Pikaboo - WOTLK ROG !youtube !skape #ad
# 4  World of Warcraft  live                                  beta m+ attacking
#
# ...

# %%
len(wow.index)
# Out:
# 1600

# %%
wow.dtypes
# Out:
# Unnamed: 0        int64
# rank              int64
# id                int64
# user_id           int64
# user_login       object
# user_name        object
# game_id           int64
# game_name        object
# type             object
# title            object
# viewer_count      int64
# started_at       object
# language         object
# thumbnail_url    object
# tag_ids          object
# is_mature          bool
# dtype: object

# %%
wow.isnull().sum()
# Out:
# Unnamed: 0       0
# rank             0
# id               0
# user_id          0
# user_login       0
# user_name        0
# game_id          0
# game_name        0
# type             0
# title            0
# viewer_count     0
# started_at       0
# language         0
# thumbnail_url    0
# tag_ids          0
# is_mature        0
# dtype: int64

# %%
from tabulate import tabulate
table_view_count = [['Game', 'view count'],
         ['Alien', alien["viewer_count"].mean()],
         ['Chess', chess["viewer_count"].mean()],
         ['Cyperpunk', cyberpunk["viewer_count"].mean()],
         ['Genshin', genshin["viewer_count"].mean()],
         ['GTA', gta["viewer_count"].mean()],
         ['Just Chatting', jc["viewer_count"].mean()],
         ['League of Legends', league["viewer_count"].mean()],
         ['Valorant', valo["viewer_count"].mean()],
         ['Virtual Casino', virtualcasino["viewer_count"].mean()],
         ['World of Warcraft', wow["viewer_count"].mean()]]
print(tabulate(table_view_count))
# Out:
# -----------------  ------------------
# Game               view count
# Alien              71.5028702640643
# Chess              144.4387755102041
# Cyperpunk          24.43328550932568
# Genshin            71.10161662817552
# GTA                341.96612296110413
# Just Chatting      1155.3149606299212
# League of Legends  88.81935483870967
# Valorant           267.8560700876095
# Virtual Casino     35.75925925925926
# World of Warcraft  310.444375
# -----------------  ------------------

# %%
table_language = [['Game', 'Language'],
         ['Alien', alien['language'].unique()],
         ['Chess', chess["language"].unique()],
         ['Cyperpunk', cyberpunk["language"].unique()],
         ['Genshin', genshin["language"].unique()],
         ['GTA', gta["language"].unique()],
         ['Just Chatting', jc["language"].unique()],
         ['League of Legends', league["language"].unique()],
         ['Valorant', valo["language"].unique()],
         ['Virtual Casino', virtualcasino["language"].unique()],
         ['World of Warcraft', wow["language"].unique()]]
print(tabulate(table_language))
# Out:
# -----------------  --------
# Game               Language
# Alien              ['en']
# Chess              ['en']
# Cyperpunk          ['en']
# Genshin            ['en']
# GTA                ['en']
# Just Chatting      ['en']
# League of Legends  ['en']
# Valorant           ['en']
# Virtual Casino     ['en']
# World of Warcraft  ['en']
# -----------------  --------

# %%
table_type = [['Game', 'Type'],
         ['Alien', alien['type'].unique()],
         ['Chess', chess["type"].unique()],
         ['Cyperpunk', cyberpunk["type"].unique()],
         ['Genshin', genshin["type"].unique()],
         ['GTA', gta["type"].unique()],
         ['Just Chatting', jc["type"].unique()],
         ['League of Legends', league["type"].unique()],
         ['Valorant', valo["type"].unique()],
         ['Virtual Casino', virtualcasino["type"].unique()],
         ['World of Warcraft', wow["type"].unique()]]
print(tabulate(table_type))
# Out:
# -----------------  --------
# Game               Type
# Alien              ['live']
# Chess              ['live']
# Cyperpunk          ['live']
# Genshin            ['live']
# GTA                ['live']
# Just Chatting      ['live']
# League of Legends  ['live']
# Valorant           ['live']
# Virtual Casino     ['live']
# World of Warcraft  ['live']
# -----------------  --------

# %% [markdown]
# All the streams were in **english** and are **live**.

# %%
table_is_mature = [['Game', 'Is Mature'],
         ['Alien', alien['is_mature'].value_counts()],
         ['Chess', chess['is_mature'].value_counts()],
         ['Cyperpunk', cyberpunk['is_mature'].value_counts()],
         ['Genshin', genshin['is_mature'].value_counts()],
         ['GTA', gta['is_mature'].value_counts()],
         ['Just Chatting', jc['is_mature'].value_counts()],
         ['League of Legends', league['is_mature'].value_counts()],
         ['Valorant', valo['is_mature'].value_counts()],
         ['Virtual Casino', virtualcasino['is_mature'].value_counts()],
         ['World of Warcraft', wow['is_mature'].value_counts()]]
print(tabulate(table_is_mature))
# Out:
# -----------------  -----------------------------
# Game               Is Mature
# Alien              True     504
#                    False    367
#                    Name: is_mature, dtype: int64
# Chess              False    503
#                    True      85
#                    Name: is_mature, dtype: int64
# Cyperpunk          True     902
#                    False    492
#                    Name: is_mature, dtype: int64
# Genshin            False    714
#                    True     585
#                    Name: is_mature, dtype: int64
# GTA                True     845
#                    False    749
#                    Name: is_mature, dtype: int64
# Just Chatting      False    905
#                    True     492
#                    Name: is_mature, dtype: int64
# League of Legends  False    380
#                    True      85
#                    Name: is_mature, dtype: int64
# Valorant           False    934
#                    True     664
# ...

# %% [markdown]
# # 3. Modeling

# %% [markdown]
# How does the content in *title* and *user_name* influence **view_count**:

# %% [markdown]
# 1. How do certain **words** influence **view_count**?
# - number of words
# - most frequently used words

# %% [markdown]
# 2. How do **emojis** influence **view_count**?

# %% [markdown]
# 3. How does **punctuation** influence **view_count**?

# %% [markdown]
# 4. How do **capitalized Letters** influence **view_count**?

# %% [markdown]
# 5. How does the boolean **is mature** Letters influence **view_count**?

# %% [markdown]
# ## 3.1 Topic Analysis Methods

# %% [markdown]
# **Natural Language Processing (NLP)** using **NLTK (Natural Language ToolKit)** and **Term Frequency Matrices (TFM)**: compute the frequency words and main topics within stream titles:
#
# - **Non Negative Matrix Factorization (NMF)**: elements of the factorized matrices are non-negative *(unobserved)*
# - **Parallel Latent Dirichlet Allocation (PLDA)**: find set of n labels associated with each topics *(unobserved)*
# - **Pachinko Allocation Model (PAM)**: improved method of Latent Dirichlet Allocation model *(unobserved)*
# - **Word2Vec**: uses neural network model to learn word associations *(unobserved)*

# %% [markdown]
# ### a) Top2Vec

# %% [markdown]
# - https://github.com/ddangelov/Top2Vec
# - https://www.youtube.com/watch?v=bEaxKSQ4Av8
# - unsupervised learning
# - find patterns in document and cluster them into topics

# %%
#put all the titles in a list
docs = alien.title.tolist()
docs
# Out:
# ["Ohh we're halfway there. WHOA-OH! XENO ON A CHAIR!!",
#  'We bring the Nightmare to Alien. !dixper !throne',
#  'First time... what am I getting myself into??',
#  '😱Horror month: Double Xenomorph time, part 2',
#  'WE BACK',
#  'morbid monday w/ aliens and falling',
#  'Am...am I doing this Spooptober thing right...? | FIRST PLAYTHROUGH OF ALIEN ISOLATION, SEND HELP | October soundalerts | JUMPSCARE WARNING',
#  'SEGA SALE! AI(Nightmare Diff) Halloween Edition! (ShortBreak)(Doom3 Nightmare !follower)Ask to see !cat (Please aggravate my GenderDysphoria',
#  'How many times will i die today T.T| ENG',
#  'Alien: Isolation - First time playthrough',
#  'No one can hear you scream is space? I beg to differ...',
#  'Alien isolation spooky time',
#  '[Alien:Isolation] Alien Meet and Greet! Wish me luck! (first playthrough)',
#  'Alien plays hide and seek 🎃 / Spooktober',
#  'Alien isolation Gameplay',
#  'Spooktember with scaredy cats',
#  'Alien isolation part 2',
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
from top2vec import Top2Vec
# Out:
# 2023-01-22 12:02:48.438652: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#create model
model = Top2Vec(docs)
# Out:
# 2023-01-22 12:02:48,756 - top2vec - INFO - Pre-processing documents for training
# 2023-01-22 12:02:48,823 - top2vec - INFO - Creating joint document/word embedding
# 2023-01-22 12:02:50,332 - top2vec - INFO - Creating lower dimension embedding of documents
# 2023-01-22 12:03:00,679 - top2vec - INFO - Finding dense areas of documents
# 2023-01-22 12:03:00,739 - top2vec - INFO - Finding topics

# %% [markdown]
# Look at the graph "numerically":

# %% [markdown]
# ![Screen%20Shot%202022-11-05%20at%2019.47.05.png](attachment:Screen%20Shot%202022-11-05%20at%2019.47.05.png)

# %%
#get the number of different topics
topic_sizes, topic_nums = model.get_topic_sizes()
print(topic_nums)
# Out:
# [0 1 2 3 4]

# %%
#get the sizes of the different topics
print(topic_sizes)
# Out:
# [213 190 167 156 145]

# %%
#find the words that make each topic unique --> a lot of overlap
topic_words, word_scores, topic_nums = model.get_topics(3)

# %%
for words, scores, num in zip(topic_words, word_scores, topic_nums):
    print(num)
    print(f"Words: {words}")
# Out:
# 0
# Words: ['game' 'alien' 'discord' 'me' 'in' 'time' 'and' 'this' 'the' 'with'
#  'first' 'to' 'spooky' 'isolation' 'playthrough']
# 1
# Words: ['first' 'to' 'time' 'the' 'isolation' 'spooky' 'playthrough' 'with'
#  'this' 'alien' 'and' 'in' 'game' 'me' 'discord']
# 2
# Words: ['discord' 'and' 'in' 'me' 'game' 'isolation' 'with' 'time' 'spooky'
#  'first' 'the' 'playthrough' 'to' 'this' 'alien']

# %% [markdown]
# Finding the **Topic Vectors** (Vector made out of words that is charateristic core for topic/ group of similar titles)

# %% [markdown]
# ![Screen%20Shot%202022-11-05%20at%2019.07.07.png](attachment:Screen%20Shot%202022-11-05%20at%2019.07.07.png)

# %% [markdown]
# Find the top 5 most titles/documents in the 1st out of the 4 clusters:

# %%
documents, documents_scores, documents_ids = model.search_documents_by_topic(topic_num=2, num_docs=3)
for doc, score, doc_id in zip(documents, documents_scores, documents_ids):
    print(f"Document: {doc_id}, Score: {score}")
    print("---------")
    print(doc)
    print("---------")
    print()
# Out:
# Document: 643, Score: 0.3726077079772949
# ---------
# WOULD YOU BE DOWN TO GET PROBED BY AN ALIEN? - Alien Isolation !youtube !discord !widers
# ---------
#
# Document: 705, Score: 0.34983664751052856
# ---------
# LETS GET SCARED TOGETHER
# ---------
#
# Document: 461, Score: 0.32696694135665894
# ---------
# This stream is gonna be a little goofy in all the wrong ways
# ---------

# %% [markdown]
# ### b) Latent Dirichlet Allocation (LDA)

# %% [markdown]
# - obtain relationships between multiple documents in a corpus
# - find groups with similar topics
# - https://www.youtube.com/watch?v=be7Xd2Ntai8

# %%
alien_lda = alien[["title"]]
alien_lda
# Out:
#                                                  title
# 0    Ohh we're halfway there. WHOA-OH! XENO ON A CH...
# 1     We bring the Nightmare to Alien. !dixper !throne
# 2        First time... what am I getting myself into??
# 3         😱Horror month: Double Xenomorph time, part 2
# 4                                              WE BACK
# ..                                                 ...
# 872                  finally jumpin in to horror games
# 873                                    alien isolating
# 874                                         scary game
# 875                                  I Hate This Alien
# 876       Space Person [first timer] (AspargTV day 46)
#
# [871 rows x 1 columns]

# %% [markdown]
# Get rid of punctuation, uppercases:

# %%
# Load the regular expression library
import re
# Remove punctuation
alien_lda['title_processed'] = \
alien_lda['title'].map(lambda x: re.sub('[,\.!?]', '', x))

# Convert the titles to lowercase
alien_lda['title_processed'] = \
alien_lda['title_processed'].map(lambda x: x.lower())

# Print out the first rows of title
alien_lda['title_processed'].head()
# Out:
# 0    ohh we're halfway there whoa-oh xeno on a chair
# 1      we bring the nightmare to alien dixper throne
# 2           first time what am i getting myself into
# 3        😱horror month: double xenomorph time part 2
# 4                                            we back
# Name: title_processed, dtype: object

# %% [markdown]
# Wordcloud just for fun:

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(alien_lda['title_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F95DADF70A0>

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
#words' maximum appearance in 95% of the titles and min in 2 titles, erase stopwords
cv = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm = cv.fit_transform(alien_lda['title'])

# %%
dtm
# Out:
# <871x526 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3575 stored elements in Compressed Sparse Row format>

# %%
#create a titlesXwords parse matrix with 4 general word topics
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=4)
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=4)

# %%
#number of different words
len(cv.get_feature_names())
# Out:
# 526

# %%
type(cv.get_feature_names())
# Out:
# list

# %%
#Grab a random vocabulary of words
cv.get_feature_names()[513]
# Out:
# 'work'

# %%
#Grab the topics, as defined above
len(LDA.components_)
# Out:
# 4

# %%
LDA.components_.shape
# Out:
# (4, 526)

# %%
LDA.components_
# Out:
# array([[0.25017161, 0.25319806, 1.93442825, ..., 0.25003287, 0.25735305,
#         0.25023197],
#        [1.54044597, 4.24010935, 1.24884771, ..., 3.24991866, 0.25465138,
#         0.26348277],
#        [0.25016687, 0.25390201, 0.25541098, ..., 0.2500331 , 8.76155909,
#         1.24384804],
#        [6.95921555, 0.25279057, 2.56131307, ..., 0.25001537, 4.72643649,
#         3.24243723]])

# %%
type(LDA.components_)
# Out:
# numpy.ndarray

# %%
single_topic = LDA.components_[0]

# %%
#find the 10 highest probability words to characterize the topic
top_ten_words = single_topic.argsort()[-10:]

# %%
#get the feature names for the index position
for index in top_ten_words: 
    print(cv.get_feature_names()[index])
# Out:
# scream
# aliens
# vtuber
# hear
# stream
# games
# space
# horror
# month
# spooky

# %%
#create a loop to print out the top 15 words for each topic
for i, topic in enumerate(LDA.components_):
    print(f"The Top 10 words for Topic #{i}")
    print([cv.get_feature_names()[index] for index in topic.argsort()[-10:]])
    print('\n')
    print('\n')
# Out:
# The Top 10 words for Topic #0
# ['scream', 'aliens', 'vtuber', 'hear', 'stream', 'games', 'space', 'horror', 'month', 'spooky']
#
#
#
#
# The Top 10 words for Topic #1
# ['just', 'discord', 'new', 'playthrough', 'day', 'stream', 'spooky', 'time', 'scary', 'game']
#
#
#
#
# The Top 10 words for Topic #2
# ['lurk', 'xenomorph', 'playthrough', 'aliens', 'mode', 'space', 'nightmare', '18', 'socials', 'discord']
#
#
#
#
# The Top 10 words for Topic #3
# ['pt', 'day', 'scared', 'play', 'time', 'spooktober', 'playthrough', 'discord', 'isolation', 'alien']

# %%
#attach a topic number to every title depending on the in the titles used words and 
#thesewords’ probability to characterize each topic
topic_results = LDA.transform(dtm)
topic_results[0]
# Out:
# array([0.08615182, 0.08334894, 0.74575981, 0.08473943])

# %%
topic_results[0].argmax()
# Out:
# 2

# %%
alien_lda["Topic"] = topic_results.argmax(axis=1)
alien_lda
# Out:
#                                                  title  \
# 0    Ohh we're halfway there. WHOA-OH! XENO ON A CH...
# 1     We bring the Nightmare to Alien. !dixper !throne
# 2        First time... what am I getting myself into??
# 3         😱Horror month: Double Xenomorph time, part 2
# 4                                              WE BACK
# ..                                                 ...
# 872                  finally jumpin in to horror games
# 873                                    alien isolating
# 874                                         scary game
# 875                                  I Hate This Alien
# 876       Space Person [first timer] (AspargTV day 46)
#
#                                      title_processed  Topic
# 0    ohh we're halfway there whoa-oh xeno on a chair      2
# 1      we bring the nightmare to alien dixper throne      2
# 2           first time what am i getting myself into      1
# 3        😱horror month: double xenomorph time part 2      0
# ...

# %% [markdown]
# ### c) Latent Semantic Analysis (LSA)

# %% [markdown]
# - extract relationship between different words in title
# - https://www.youtube.com/watch?v=BJ0MnawUpaU

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# **TF-IDF Vectorization**

# %%
#use TF-IDF Vectorization and stopwords to remove unimportant words
docs = alien.title.tolist()
stopset = set(stopwords.words('english'))
stopset.update(["first"])

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,
                             use_idf=True, ngram_range=(1, 3))
X = vectorizer.fit_transform(docs)

# %%
X[0]
# Out:
# <1x7555 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>

# %%
print(X[0])
# Out:
#   (0, 4720)	0.2664818009300199
#   (0, 7291)	0.2664818009300199
#   (0, 2964)	0.2664818009300199
#   (0, 4723)	0.2664818009300199
#   (0, 7385)	0.2664818009300199
#   (0, 4719)	0.2664818009300199
#   (0, 7290)	0.2664818009300199
#   (0, 2963)	0.2664818009300199
#   (0, 4722)	0.2664818009300199
#   (0, 1341)	0.2664818009300199
#   (0, 7380)	0.19600618236450132
#   (0, 4698)	0.19600618236450132
#   (0, 7289)	0.2664818009300199
#   (0, 2962)	0.2664818009300199
#   (0, 4721)	0.2664818009300199

# %% [markdown]
# **LSA**

# %%
#matrix of titles X total words
X.shape
# Out:
# (871, 7555)

# %%
#decompose the matrix to find 10 topics
lsa = TruncatedSVD(n_components=5, n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(n_components=5, n_iter=100)

# %%
lsa.components_[0]
# Out:
# array([9.71365155e-04, 4.85682577e-04, 4.85682577e-04, ...,
#        4.11513548e-05, 4.11513548e-05, 4.11513548e-05])

# %%
#find the words which characterize the the topics
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_):
    termsInComp = zip (terms,comp)
    sortedTerms = sorted(termsInComp, key=lambda x: x[1], reverse=True) [:7]
    print("Concept %d:" %i)
    for term in sortedTerms:
        print(term[0])
    print(" ")
# Out:
# Concept 0:
# alien
# alien isolation
# isolation
# part
# playthrough
# alien isolation part
# isolation part
#
# Concept 1:
# game
# scary
# scary game
# spooky
# month
# playing
# playing scary
#
# Concept 2:
# hear
# one hear
# one
# space
# space one
# space one hear
# hear scream
#
# Concept 3:
# spooky
# season
# spooky season
# time
# isolation
# alien isolation
# month
#
# Concept 4:
# alien
# spooky
# season
# spooky season
# time
# spooky month
# hate alien

# %% [markdown]
#  ## 3.2 Advanced Exploratory Text Analysis

# %% [markdown]
# https://towardsdatascience.com/exploratory-text-analysis-in-python-8cf42b758d9e
# 1. Data Split into train & test data
# 2. Extraction of short (less than 4 tokens) and long (more than 15 tokens) strings
# 3. Frequency of specific charateristics (numbers, hyphenated words, words combined by punctuation, words with at least 1 captalized letter, words with at least 1 lowercase letter emojis) in strings
# 4. Other Token Characteristics
# 5. Stopwords Removal
# 6. Most common groups of 1, 2, 3 and 4 tokens
# 7. Average number of sentences, tokens, characters, stop words per title

# %%
import nltk
nltk.download('punkt') # for sent_tokenize 
nltk.download('wordnet') # for WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/paulschumacher/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/paulschumacher/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Setting random seed
seed = 123

# Data partitioning
from sklearn.model_selection import train_test_split
# Text preprocessing/analysis
import re
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
# Visualisation
sns.set(style="whitegrid", context='talk', 
        palette=['#D44D5C', '#43AA8B'])

# %% [markdown]
# #### Split data into train & test data

# %%
train, test = train_test_split(alien_ML['title'], test_size=176, random_state=seed)

# Append sentiment back using indices
train = pd.concat([train], axis=1)
test = pd.concat([test], axis=1)

# Check dimensions
print(f"Train: {train.shape[0]} rows and {train.shape[1]} columns")
print(f"Test: {test.shape[0]} rows and {test.shape[1]} columns")
# Out:
# Train: 695 rows and 1 columns
# Test: 176 rows and 1 columns

# %%
train.head()
# Out:
#                                                  title
# 102                       First time Spoopy Space game
# 255                      Giving the alien some company
# 267  🍀 Post-Con Plague & Raising Money for St Jude ...
# 390  We Found Our Crewmates! But We Also Need A Med...
# 107                   FIRST SPOOKY GAME OF THE SEASON!

# %%
test.head()
# Out:
#                                                  title
# 312                                              Alien
# 54   Let's try and survive in space with an alien o...
# 365  October Horror month! I'll be playing horror b...
# 570                                                Tod
# 805                                    xx✔4\3 fulton\5

# %% [markdown]
# Exploratory text analysis of train and test data

# %%
# Prepare training corpus into one giant string
train_string = "".join(str(train.values))

# Split train_corpus by white space
splits = train_string.split()

# %%
train_string
# Out:
# '[[\'First time Spoopy Space game\']\n [\'Giving the alien some company\']\n [\'🍀 Post-Con Plague & Raising Money for St Jude !donate | [Nightmare] 🍀\']\n [\'We Found Our Crewmates! But We Also Need A Medic!! 👽 Alien Isolation | Spooky Horror Night 13👻👹🙈🙊 |GOW After Some Jump Scares 🧔🪓🏹\']\n [\'FIRST SPOOKY GAME OF THE SEASON!\']\n [\'alien isolation vr w/ heart monitor !xeno\']\n ["Alien: Isolation continues | No Man\'s Sky Drops later"]\n [\'playing a "scary" game\']\n [\'Screamtober Stream Marathon!!!\']\n [\'Alien Isolation.\']\n [\'[TSAN] save me!\']\n [\'Sci-fi Spooky Time\']\n [\'Wait, what is this!? | 54/100 to StreamRaiders! | 18+\']\n [\'1st Playthrough of Alien Isolation. Time to get Spooked!\']\n [\'wicked weekends! | !discord | !twitter | !insta\']\n ["Listen to me whimper! I\'m going to actually play this game through this time!"]\n [\'#XboxSX #PS5 killing time Alien Isolation\']\n [\'hmmm a derust? ❤️ AM NMG NM nopout% | !focus !rip !yescali !sfx !STEVEN\']\n [\'Spooky
# ...

# %%
splits
# Out:
# ["[['First",
#  'time',
#  'Spoopy',
#  'Space',
#  "game']",
#  "['Giving",
#  'the',
#  'alien',
#  'some',
#  "company']",
#  "['🍀",
#  'Post-Con',
#  'Plague',
#  '&',
#  'Raising',
#  'Money',
#  'for',
#  'St',
#  'Jude',
#  '!donate',
#  '|',
#  '[Nightmare]',
#  "🍀']",
#  "['We",
#  'Found',
#  'Our',
#  'Crewmates!',
#  'But',
#  'We',
#  'Also',
#  'Need',
#  'A',
#  'Medic!!',
#  '👽',
#  'Alien',
#  'Isolation',
#  '|',
#  'Spooky',
#  'Horror',
#  'Night',
#  '13👻👹🙈🙊',
#  '|GOW',
#  'After',
#  'Some',
#  'Jump',
#  'Scares',
#  "🧔🪓🏹']",
#  "['FIRST",
#  'SPOOKY',
#  'GAME',
#  'OF',
#  'THE',
#  "SEASON!']",
#  "['alien",
#  'isolation',
#  'vr',
#  'w/',
#  'heart',
#  'monitor',
#  "!xeno']",
#  '["Alien:',
#  'Isolation',
#  'continues',
#  '|',
#  'No',
#  "Man's",
#  'Sky',
#  'Drops',
#  'later"]',
#  "['playing",
#  'a',
#  '"scary"',
#  "game']",
#  "['Screamtober",
#  'Stream',
#  "Marathon!!!']",
#  "['Alien",
#  "Isolation.']",
#  "['[TSAN]",
#  'save',
# ...

# %%
print(f"Number of strings: {len(splits)}")
print(f"Number of unique strings: {len(set(splits))}")
# Out:
# Number of strings: 5799
# Number of unique strings: 2835

# %%
freq_splits = FreqDist(splits)
print(f"***** 10 most common strings ***** \n{freq_splits.most_common(10)}", "\n")
# Out:
# ***** 10 most common strings *****
# [('|', 192), ('Alien', 98), ('Isolation', 94), ('-', 73), ('to', 66), ('the', 65), ('with', 49), ('a', 47), ('and', 44), ("['Alien", 40)]

# %% [markdown]
# #### Extract short (less than 4 tokens) and long (more than 15 tokens) strings

# %%
short = set(s for s in splits if len(s)<4)
short = [(s, freq_splits[s]) for s in short]
short.sort(key=lambda x:x[1], reverse=True)
short
# Out:
# [('|', 192),
#  ('-', 73),
#  ('to', 66),
#  ('the', 65),
#  ('a', 47),
#  ('and', 44),
#  ('I', 34),
#  ('of', 32),
#  ('for', 32),
#  ('is', 24),
#  ('in', 22),
#  ('you', 21),
#  ('Day', 20),
#  ('me', 19),
#  ('my', 17),
#  ('on', 16),
#  ('The', 15),
#  ("['I", 15),
#  ('||', 15),
#  ('get', 14),
#  ('no', 14),
#  ('be', 14),
#  ('one', 13),
#  ('it', 13),
#  ('are', 12),
#  ('can', 12),
#  ('&', 12),
#  ('2', 11),
#  ('not', 11),
#  ('THE', 10),
#  ('In', 10),
#  ('we', 10),
#  ('at', 9),
#  ('/', 9),
#  ('GET', 9),
#  ('A', 9),
#  ('day', 8),
#  (':', 8),
#  ('do', 8),
#  ('No', 8),
#  ('ON', 8),
#  ('Can', 8),
#  ('One', 7),
#  ('~', 7),
#  ('an', 7),
#  ('You', 7),
#  ('out', 7),
#  ('//', 7),
#  ('18+', 7),
#  ('but', 7),
#  ('i', 7),
#  ('To', 7),
#  ('vs', 7),
#  ('am', 6),
#  ("2']", 6),
#  ("I'm", 6),
#  ('DAY', 6),
#  ('AND', 6),
#  ('TO', 6),
#  ('🎃', 5),
#  ('by', 5),
#  ('big', 5),
#  ('its', 5),
#  ('New', 5),
#  ('or', 5),
#  ('👽', 4),
#  ('Me', 4),
#  ('We', 4),
# ...

# %%
long = set(s for s in splits if len(s)>15)
long = [(s, freq_splits[s]) for s in long]
long.sort(key=lambda x:x[1], reverse=True)
long
# Out:
# [("!streamraiders']", 2),
#  ('friendly☢️||🕹️Games🕹️#', 2),
#  ('#LitHallowSeries', 2),
#  ("!wheelofzoinks']", 2),
#  ("helppppp!!!!!!!!']", 1),
#  ('NOW😍POGGERS😍#1PLAYER😍"]', 1),
#  ("['BLIND(4:20)PLAYTHROUGH']", 1),
#  ("BABIES\\U0001fae3👽']", 1),
#  ("['🔔[AUS▪︎ENG▪︎18+]", 1),
#  ("Twitch😜✨💕!rogue💕🕹🤞']", 1),
#  ("#EnterTheDreamscape']", 1),
#  ('#spookystreams"]', 1),
#  ("{!streamloots-!discord-!twitter}']", 1),
#  ("GenderDysphoria']", 1),
#  ("['Anatidaephobia,", 1),
#  ('Followers🖤ALERTS', 1),
#  ("games🧟\\u200d♂️🧛\\u200d♂️👻🎃']", 1),
#  ('(ShortBreak)(Doom3', 1),
#  ('SPOOOOOOOOOKYMONTH', 1),
#  ("['[Alien:Isolation]", 1),
#  ('FRANCESCA/AILEEN!!', 1),
#  ('Xeno-mommies...fetishes?', 1),
#  ('#shirtmysurvivor"]', 1),
#  ('STUFF🟥E-BOY🟥CUTE🟥POGGERS🟥S-TIER', 1),
#  ('!Showyourstripes', 1),
#  ("['RIIIIIIIIIIIPLY']", 1),
#  ("['18+[She/Her/kitty/snep]", 1),
#  ("['🎃HALLOWSTREAM™", 1),
#  ('#PokemonCommunityGame"]', 1),
#  ("xenomorph....woo?']", 1),
#  ("<:9/1.01.00r3µ']", 1),
# ...

# %% [markdown]
# #### How frequent are specific charateristics in strings?
# - numbers
# - hyphenated words
# - words combined by punctuation?
# - words with at least 1 captalized letter
# - words with at least 1 lowercase letter
# - emojis

# %%
def summarise(pattern, strings, freq):
    """Summarise strings matching a pattern."""
    # Find matches
    compiled_pattern = re.compile(pattern)
    matches = [s for s in strings if compiled_pattern.search(s)]
    
    # Print volume and proportion of matches
    print("{} strings, that is {:.2%} of total".format(len(matches), len(matches)/ len(strings)))
    
    # Create list of tuples containing matches and their frequency
    output = [(s, freq[s]) for s in set(matches)]
    output.sort(key=lambda x:x[1], reverse=True)
    
    return output

# %%
#how frequent are numbers?
summarise(r"\d", splits, freq_splits)
# Out:
# 245 strings, that is 4.22% of total
# [('2', 11),
#  ('18+', 7),
#  ("2']", 6),
#  ("['[18+]", 6),
#  ("['12", 4),
#  ("4']", 4),
#  ("3']", 4),
#  ('20', 3),
#  ("5']", 3),
#  ("['[1st", 3),
#  ('6', 3),
#  ('3', 3),
#  ("2)']", 3),
#  ('!8ball', 3),
#  ('1st', 3),
#  ("18+']", 3),
#  ("['1st", 3),
#  ('Pt.2', 2),
#  (":3']", 2),
#  ('7', 2),
#  ('3"]', 2),
#  ('500', 2),
#  ('12', 2),
#  ("3!!']", 2),
#  ('Pt.3', 2),
#  ('2"]', 2),
#  ('4!', 2),
#  ('2]', 2),
#  ('2019', 2),
#  ('(PS4)', 2),
#  ('2:', 2),
#  ("8']", 2),
#  ('1', 2),
#  ("<3']", 2),
#  ('//☢️🎃🍁||☢️420', 2),
#  ('250', 2),
#  ('[18+]', 2),
#  ("['(18+)", 2),
#  ('21,', 2),
#  ('1,', 2),
#  ("1']", 2),
#  ('18+"]', 2),
#  ('OW2', 2),
#  ('HayHay_69', 2),
#  ('200)', 1),
#  ("5🚀']", 1),
#  ("10/7/22']", 1),
#  ("【#1】']", 1),
#  ('RE7,', 1),
#  ('(ShortBreak)(Doom3', 1),
#  ("['[76]", 1),
#  ('1"]', 1),
#  ('4!!', 1),
#  ('["18|', 1),
#  ("#8']", 1),
#  ('$5', 1),
#  ('e28"]', 1),
#  ('7/31}"]', 1),
# ...

# %%
#How frequent are hyphenated words?
summarise(r"\w+-+\w+", splits, freq_splits)
# Out:
# 35 strings, that is 0.60% of total
# [('V-Rex', 2),
#  ('Play-through', 2),
#  ("['Sci-fi", 1),
#  ('Half-robotic,', 1),
#  ('Post-Con', 1),
#  ('["Xeno-mommy', 1),
#  ('Face-Hugs!!👽', 1),
#  ('Isolation-COME', 1),
#  ('Xeno-mommies...fetishes?', 1),
#  ('STUFF🟥E-BOY🟥CUTE🟥POGGERS🟥S-TIER', 1),
#  ('70-99', 1),
#  ('A-Z|', 1),
#  ('Mis-Adventures', 1),
#  ('SCARE-nanigans!', 1),
#  ("Gorilla-HQ.com']", 1),
#  ('No-one', 1),
#  ('Xenobla-Xenomorph', 1),
#  ('no-one', 1),
#  ('time-Spooky', 1),
#  ('Weyland-Yutani!', 1),
#  ('PRE-DEBUT', 1),
#  ('late--had', 1),
#  ('ALIENS-Best', 1),
#  ('["Shock-Tober', 1),
#  ("0-0;']", 1),
#  ('Butt-Mare', 1),
#  ('["Step-Alien,', 1),
#  ('Games-fest', 1),
#  ('Nuclear-powered', 1),
#  ('["HORR-OCTOBER!!', 1),
#  ('WHOA-OH!', 1),
#  ('(DE-LISH)"]', 1),
#  ("Badro_mco-DZ91']", 1)]

# %%
#How frequent are words combined by punctuation?
summarise(r"\w+[_!&/)(<\|}?$@(\),.=%|>&§^*!_{\}:;+{\[\]]\w+", splits, freq_splits)
# Out:
# 60 strings, that is 1.03% of total
# [('Pt.2', 2),
#  ('Pt.3', 2),
#  ('HayHay_69', 2),
#  ('!follower)Ask', 1),
#  ('Vibes]Playing', 1),
#  ('T.T|', 1),
#  ("['BLIND(4:20)PLAYTHROUGH']", 1),
#  ('19/30', 1),
#  ("39/40']", 1),
#  ("10/7/22']", 1),
#  ("(320/325)']", 1),
#  ('10/8"]', 1),
#  ("['[EN/DE]", 1),
#  ('2.0', 1),
#  ("['ow2/koc/ai']", 1),
#  ('Aliens&Joes', 1),
#  ("101/150']", 1),
#  ("pt.3!!!']", 1),
#  ('Ep.1', 1),
#  ("['[Alien:Isolation]", 1),
#  ('Al(ein)', 1),
#  ('FRANCESCA/AILEEN!!', 1),
#  ('54/100', 1),
#  ('ʇ*ɥs', 1),
#  ('<=2:45', 1),
#  ("['18+[She/Her/kitty/snep]", 1),
#  ("PT2.5']", 1),
#  ('[16/10]"]', 1),
#  ('stream/october', 1),
#  (':shushing_face:', 1),
#  ("['[Furry|Good", 1),
#  ("['[EN/DK]", 1),
#  ('10/9"]', 1),
#  ("<:9/1.01.00r3µ']", 1),
#  ('b*tchess"]', 1),
#  ("Gorilla-HQ.com']", 1),
#  ('7/31}"]', 1),
#  ("['[ENG/PT]", 1),
#  ('AI(Nightmare', 1),
#  ('7/31', 1),
#  ('(11/50)', 1),
#  ('w/heart', 1),
#  ("#plat43(1469/1500)']", 1),
# ...

# %%
#How frequent are capitalized words?
summarise(r"[A-Z]", splits, freq_splits)
# Out:
# 2713 strings, that is 46.78% of total
# [('Alien', 98),
#  ('Isolation', 94),
#  ("['Alien", 40),
#  ('I', 34),
#  ('Alien:', 33),
#  ("Isolation']", 23),
#  ('Day', 20),
#  ('First', 18),
#  ('ALIEN', 17),
#  ("['Alien:", 17),
#  ("['Spooky", 16),
#  ('The', 15),
#  ("['I", 15),
#  ('Spooky', 13),
#  ('Xenomorph', 12),
#  ("['First", 11),
#  ('In', 10),
#  ('Horror', 10),
#  ('Space', 10),
#  ('Nightmare', 10),
#  ('THE', 10),
#  ('Part', 9),
#  ('Stream', 9),
#  ('A', 9),
#  ("['The", 9),
#  ('GAME', 9),
#  ('GET', 9),
#  ('ISOLATION', 8),
#  ('Time', 8),
#  ('Playing', 8),
#  ('This', 8),
#  ('ON', 8),
#  ('Can', 8),
#  ('Isolation.', 8),
#  ('Playthrough', 8),
#  ('No', 8),
#  ('Month', 8),
#  ("Let's", 8),
#  ('One', 7),
#  ("['This", 7),
#  ("['In", 7),
#  ('Hear', 7),
#  ('!Discord', 7),
#  ('You', 7),
#  ('Play', 7),
#  ('Spoopy', 7),
#  ('To', 7),
#  ('DAY', 6),
#  ('AND', 6),
#  ('Come', 6),
#  ('October', 6),
#  ('Night', 6),
#  ('PLAYTHROUGH', 6),
#  ('FIRST', 6),
# ...

# %%
#How frequent are lowercase words?
summarise(r"[a-z]", splits, freq_splits)
# Out:
# 4337 strings, that is 74.79% of total
# [('Alien', 98),
#  ('Isolation', 94),
#  ('to', 66),
#  ('the', 65),
#  ('with', 49),
#  ('a', 47),
#  ('and', 44),
#  ("['Alien", 40),
#  ('!discord', 33),
#  ('Alien:', 33),
#  ('of', 32),
#  ('for', 32),
#  ('this', 30),
#  ('alien', 26),
#  ('is', 24),
#  ("Isolation']", 23),
#  ('in', 22),
#  ('game', 21),
#  ('you', 21),
#  ('Day', 20),
#  ('me', 19),
#  ('First', 18),
#  ("['Alien:", 17),
#  ('my', 17),
#  ("!socials']", 16),
#  ('on', 16),
#  ("['Spooky", 16),
#  ('time', 16),
#  ('!socials', 15),
#  ('The', 15),
#  ('space', 15),
#  ("!discord']", 15),
#  ('scary', 15),
#  ('get', 14),
#  ('no', 14),
#  ('spooky', 14),
#  ('be', 14),
#  ('one', 13),
#  ('Spooky', 13),
#  ('isolation', 13),
#  ('it', 13),
#  ('are', 12),
#  ('Xenomorph', 12),
#  ('will', 12),
#  ('can', 12),
#  ('stream', 12),
#  ('hear', 11),
#  ('not', 11),
#  ('some', 11),
#  ("['First", 11),
#  ('In', 10),
#  ('Horror', 10),
#  ('Space', 10),
#  ('Nightmare', 10),
# ...

# %%
#How frequent are emojis?
def extract_emojis(s):
  return ''.join(c for c in s if c in emoji.UNICODE_EMOJI['en'])

is_emojis = [s for s in splits if extract_emojis(s)]
print("{} strings, that is {:.2%} of total".format(len(is_emojis), len(is_emojis)/ len(splits)))
emojis = [(s, freq_splits[s]) for s in set(is_emojis)]
emojis.sort(key=lambda x:x[1], reverse=True)
emojis
# Out:
# 154 strings, that is 2.66% of total
# [('🎃', 5),
#  ('👽', 4),
#  ('🛸', 4),
#  ('❤️', 3),
#  ('❗commands', 3),
#  ("❗patreon']", 3),
#  ("['💀️", 3),
#  ("['🍁", 2),
#  ("🍀']", 2),
#  ('🎃👻🎃', 2),
#  ("['🦐", 2),
#  ('💨#', 2),
#  ("['[Vtuber]💙", 2),
#  ("['👽", 2),
#  ("['❤️", 2),
#  ("['🎃👻🎃", 2),
#  ('💙', 2),
#  ("🍁']", 2),
#  ("['😱Horror", 2),
#  ('friendly☢️||🕹️Games🕹️#', 2),
#  ("['🍀", 2),
#  ('😅', 2),
#  ("!soup❤️']", 2),
#  ('//☢️🎃🍁||☢️420', 2),
#  ('Chat🔞', 2),
#  ("['||🍁🎃☢️\\\\\\\\", 2),
#  ("['🔴[FIRST", 2),
#  ("MVP🌀||']", 2),
#  ('||🌀Official', 2),
#  ('AI?😱', 2),
#  ('😱WILL', 2),
#  ('SUB]🦊||', 1),
#  ("['👽Free", 1),
#  ("👻👻👻']", 1),
#  ("5🚀']", 1),
#  ('SEEN😍CLICK', 1),
#  ("['🚀Alien", 1),
#  ("['🟥CLICK", 1),
#  ("['🖤POV:", 1),
#  ("['xx✔']", 1),
#  ('HALLOWSTREAM™', 1),
#  ("['🐻", 1),
#  ("NIGHT🔥']", 1),
#  ("luck😰💀']", 1),
#  ('♥', 1),
#  ('CHARACTER🟥RETURNING🟥AS', 1),
#  ('isolation🐝🖤', 1),
#  ('FAST🟥NEW', 1),
#  ('😈', 1),
#  ('["✨️(Vtuber)', 1),
#  ("🖤']", 1),
#  ('😱', 1),
# ...

# %%
#how frequent are words that contain a same character 3+ times in a row?
def find_outlaw(word):
    is_outlaw = False
    for i, letter in enumerate(word):
        if i > 1:
            if word[i] == word[i-1] == word[i-2] and word[i].isalpha():
                is_outlaw = True
                break
    return is_outlaw
outlaws = [s for s in splits if find_outlaw(s)]
print("{} strings, that is {:.2%} of total".format(len(outlaws), len(outlaws)/ len(splits)))
outlaw_freq = [(s, freq_splits[s]) for s in set(outlaws)]
outlaw_freq.sort(key=lambda x:x[1], reverse=True)
outlaw_freq
# Out:
# 23 strings, that is 0.40% of total
# [("['oooOOOOooooo", 2),
#  ("helppppp!!!!!!!!']", 1),
#  ('burrrrrrrrn', 1),
#  ('MISSSING', 1),
#  ('Shhhh...there', 1),
#  ('SPOOOOOOOOOKYMONTH', 1),
#  ("['RIIIIIIIIIIIPLY']", 1),
#  ('ATTTTT', 1),
#  ('gettting', 1),
#  ('AAAA', 1),
#  ('faceee', 1),
#  ('*Hisssss*', 1),
#  ('GOOO', 1),
#  ("MEEEEEE!!!!!!!!']", 1),
#  ('uhhh,', 1),
#  ('fireeeeee', 1),
#  ("['Aaaaand", 1),
#  ('gooo"]', 1),
#  ('mannnn', 1),
#  ("givingggggg...alienussy']", 1),
#  ("['hmmm", 1),
#  ('MEEEEEEEEE', 1)]

# %% [markdown]
# #### Other Token Characteristics

# %%
#the 20 most common tokens/words
tokeniser = RegexpTokenizer("[A-Za-z]+")
tokens = tokeniser.tokenize(train_string)
print(tokens[:20], "\n")
# Out:
# ['First', 'time', 'Spoopy', 'Space', 'game', 'Giving', 'the', 'alien', 'some', 'company', 'Post', 'Con', 'Plague', 'Raising', 'Money', 'for', 'St', 'Jude', 'donate', 'Nightmare']

# %%
print(f"Number of tokens: {len(tokens)}")
print(f"Number of unique tokens: {len(set(tokens))}")
# Out:
# Number of tokens: 5384
# Number of unique tokens: 1978

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/paulschumacher/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#normalise tokens to the word stems (watch, watched, watching will count as 1)
lemmatiser = WordNetLemmatizer()
tokens_norm = [lemmatiser.lemmatize(t.lower(), "v") for t in tokens]
print(f"Number of unique tokens: {len(set(tokens_norm))}")
# Out:
# Number of unique tokens: 1356

# %%
#lengths for each token
token_length = [len(t) for t in tokens]

# Average number of characters per token
print(f"Average number of characters per token: {round(np.mean(token_length),4)}")
# Plot distribution
plt.figure(figsize=(12, 12))
sns.countplot(y=token_length)
plt.title("Counts of token length", size=20);
# Out:
# Average number of characters per token: 4.8425

# %%
#look at longer tokens
pd.DataFrame(data=token_length, 
             columns=['length']).query("length>10").value_counts()
# Out:
# length
# 11        71
# 12        12
# 13        12
# 14         7
# 15         7
# 18         2
# 16         1
# 20         1
# dtype: int64

# %%
#look at the longest token
[t for t in tokens if len(t)>=20]
# Out:
# ['PokemonCommunityGame']

# %% [markdown]
# #### Remove Stopwords

# %%
stop_words = stopwords.words("english")
stop_words.extend(["cannot", "could", "done", "let", "may" "mayn",  "might", "must", "need", "ought", "oughtn", "shall", "would", "br"])
print(f"There are {len(stop_words)} stopwords.\n")
# Out:
# There are 192 stopwords.

# %%
freq_stopwords = [(sw, tokens_norm.count(sw)) for sw in stop_words]
freq_stopwords.sort(key=lambda x: x[1], reverse=True)
freq_stopwords[:10]
# Out:
# [('the', 106),
#  ('be', 87),
#  ('i', 81),
#  ('to', 80),
#  ('a', 61),
#  ('this', 59),
#  ('with', 58),
#  ('and', 51),
#  ('s', 49),
#  ('in', 46)]

# %%
n_stopwords = len([t for t in tokens_norm if t in stop_words])
print(f"{n_stopwords} tokens are stop words.")
print(f"That is {round(100*n_stopwords/len(tokens_norm),2)}%.")
# Out:
# 1528 tokens are stop words.
# That is 28.38%.

# %%
tokens_clean = [t for t in tokens_norm if t not in stop_words]
print(f"Number of tokens: {len(tokens_clean)}")
# Out:
# Number of tokens: 3856

# %% [markdown]
# #### Find most common groups of one, two, three and four tokens

# %%
def preprocess_text(text):
    """Preprocess text into normalised tokens."""
    # Tokenise words into alphabetic tokens
    tokeniser = RegexpTokenizer(r'[A-Za-z]{2,}')
    tokens = tokeniser.tokenize(text)
    
    # Lowercase and lemmatise 
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(token.lower(), pos='v') for token in tokens]
    
    # Remove stopwords
    keywords= [lemma for lemma in lemmas if lemma not in stop_words]
    return keywords
def get_frequent_ngram(corpus, ngram, n=20):
    """Find most common n n-grams tokens."""
    # Preprocess each document
    documents = [preprocess_text(document) for document in corpus]
    
    # Find ngrams per document
    n_grams = [list(ngrams(document, ngram)) for document in documents]
    
    # Find frequency of ngrams
    n_grams_flattened = [item for sublist in n_grams for item in sublist]
    freq_dist = FreqDist(n_grams_flattened)
    top_freq = freq_dist.most_common(n)
    return pd.DataFrame(top_freq, columns=["ngram", "count"])
# Get frequent ngrams for all 4
for i in range(1,5):
    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}
    plt.figure(figsize=(12,10))
    sns.barplot(x="count", y="ngram", data=get_frequent_ngram(train['title'], i))
    plt.title(f"Most common {mapping[i]}grams");

# %% [markdown]
# #### What is the average number of **sentences, tokens, characters, stop words** per title?

# %%
# tokeniser = RegexpTokenizer("[A-Za-z]+")
train["n_sentences"] = train["title"].apply(sent_tokenize).apply(len)
train["tokens"] = train["title"].apply(tokeniser.tokenize)
train["n_tokens"] = train["tokens"].apply(len)
train["n_characters"] = train["title"].apply(len)
train["n_stopwords"] = train["tokens"].apply(lambda tokens: len([t for t in tokens if t in stop_words]))
# Inspect head
columns = ['n_sentences', 'n_tokens', 'n_characters', 'n_stopwords']
train[columns].head()
# Out:
#      n_sentences  n_tokens  n_characters  n_stopwords
# 102            1         5            28            0
# 255            1         5            29            2
# 267            1        10            69            1
# 390            3        20           129            0
# 107            1         6            32            0

# %%
train.describe()
# Out:
#        n_sentences    n_tokens  n_characters  n_stopwords
# count   695.000000  695.000000    695.000000   695.000000
# mean      1.398561    7.738129     49.356835     1.434532
# std       0.688102    4.593935     28.519358     1.966862
# min       1.000000    1.000000      3.000000     0.000000
# 25%       1.000000    4.000000     27.000000     0.000000
# 50%       1.000000    7.000000     46.000000     1.000000
# 75%       2.000000   10.000000     65.000000     2.000000
# max       5.000000   27.000000    140.000000    12.000000

# %%
num_vars = train.select_dtypes(np.number).columns

# %%
def plot_distribution(df, var):
    """Plot overlayed histogram and density plot"""
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=[16,4])
    
    # Histogram
    sns.histplot(data=df, x=var, bins=30, kde=False, ax=ax[0])
    ax[0].set_title(f"Histogram for {var}")
    
    # Density plot
    sns.kdeplot(data=df, x=var, shade=True, ax=ax[1])
    ax[1].set_title(f"Density plot for {var}");

    # Plot for all numerical variables
for var in num_vars:
    plot_distribution(train, var)

# %% [markdown]
# ## 3.3 Three different Machine Learning Methods

# %% [markdown]
# ##### What are we trying to analyse? --> Viewercount is not correlated to any of the given values

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %% [markdown]
# Cut redundant and add quantitative variables to the data set:

# %%
alien_ML = alien.loc[:, ~alien.columns.isin(['user_id','rank','game_id','type','language',
                                  'thumbnail_url','game_name','Unnamed: 0',
                                 'user_login', 'id', 'tag_ids'])]
alien_ML.head()
# Out:
#       user_name                                              title  \
# 0  glowpinkstah  Ohh we're halfway there. WHOA-OH! XENO ON A CH...
# 1    DKittyCone   We bring the Nightmare to Alien. !dixper !throne
# 2     FatalFayt      First time... what am I getting myself into??
# 3     Eurosdown       😱Horror month: Double Xenomorph time, part 2
# 4   LilMeliBebe                                            WE BACK
#
#    viewer_count            started_at  is_mature
# 0            50  2022-10-10T15:32:11Z       True
# 1            34  2022-10-10T10:00:16Z       True
# 2            15  2022-10-10T14:02:41Z       True
# 3            11  2022-10-10T15:55:17Z      False
# 4             9  2022-10-10T13:02:37Z      False

# %%
def extract_emojis(s):
  return ''.join(c for c in s if c in emoji.UNICODE_EMOJI['en'])

# %%
#add more variables for ML
alien_ML['Lenght Username'] = alien['user_name'].str.len()
alien_ML['Lenght Title'] = alien['title'].str.len()
alien_ML['is_mature'] = alien_ML['is_mature'].astype(int)

#number uppercase letters
alien_ML['Number_Uppercase'] = alien['title'].str.findall(r'[A-Z]').str.len()
alien_ML['%_Uppercase'] = alien_ML['Number_Uppercase']/alien_ML['Lenght Title']

#number special characters
alien_ML['Number_Special_Charakters'] = alien['title'].str.findall(r'[?$@!#/\%|&§^*_{}:;+(),.=<">-]').str.len()
alien_ML['%_Special_Charakters'] = alien_ML['Number_Special_Charakters']/alien_ML['Lenght Title']

#number of emojis
alien_ML['Number_Emojis'] = alien['title'].apply(extract_emojis).str.len()
alien_ML['%_Emojis'] = alien_ML['Number_Emojis']/alien_ML['Lenght Title']

alien_ML.head()
# Out:
#       user_name                                              title  \
# 0  glowpinkstah  Ohh we're halfway there. WHOA-OH! XENO ON A CH...
# 1    DKittyCone   We bring the Nightmare to Alien. !dixper !throne
# 2     FatalFayt      First time... what am I getting myself into??
# 3     Eurosdown       😱Horror month: Double Xenomorph time, part 2
# 4   LilMeliBebe                                            WE BACK
#
#    viewer_count            started_at  is_mature  Lenght Username  \
# 0            50  2022-10-10T15:32:11Z          1               12
# 1            34  2022-10-10T10:00:16Z          1               10
# 2            15  2022-10-10T14:02:41Z          1                9
# 3            11  2022-10-10T15:55:17Z          0                9
# 4             9  2022-10-10T13:02:37Z          0               11
#
#    Lenght Title  Number_Uppercase  %_Uppercase  Number_Special_Charakters  \
# 0            51                19     0.372549                          5
# ...

# %% [markdown]
#  a) **Clustering** using **K-Means** (group or cluster observations that have similar characteristics)

# %% [markdown]
# b) **Random Forest Classifier** as complex Regression (elements in titles don't have a linear relationship with each other) with **rolling average** (current viewership influences the opcoming one because of the algorithm)

# %% [markdown]
# c) Simple **Multilinear Regression** (influence of words, emojis, punctions, capitalized letters, ... on view_count)
